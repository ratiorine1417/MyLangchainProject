# %%
#poetry add langchain-google-genai

# %%
from dotenv import load_dotenv
import os
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv(dotenv_path='../.env')

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
print(GOOGLE_API_KEY[:4])
# Out:
# AIza

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
    
# API 키 설정
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key"

# 모델 초기화
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",  # 또는 "gemini-pro-vision"
    temperature=0.3    
)

# 프롬프트 설정
prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 AI 전문가입니다."),
    ("human", "{topic}은 무엇인가요?")
])

# 체인 실행
chain = prompt | llm
response = chain.invoke({"topic": "LangChain과 LangGraph"})

print(" Google Gemini Response:")
print(response.content)
# Out:
#  Google Gemini Response:
# LangChain과 LangGraph는 모두 대규모 언어 모델(LLM)을 중심으로 한 응용 프로그램을 구축하기 위한 프레임워크이지만, 접근 방식과 초점이 다릅니다.  두 프레임워크를 비교하면 다음과 같습니다.
#
# **LangChain:**
#
# * **초점:** LLM 기반 애플리케이션을 구축하기 위한 **모듈식 프레임워크**.  LLM을 다양한 데이터 소스와 연결하고, 메모리, 체인, 에이전트 등의 기능을 제공하여 복잡한 작업을 수행할 수 있도록 합니다.  즉, LLM을 핵심으로 하여 다양한 기능을 추가하고 확장하는 데 중점을 둡니다.
# * **핵심 기능:**
#     * **모듈:** 다양한 LLM, 데이터 소스, 프로세서를 모듈화하여 재사용성과 확장성을 높입니다.
#     * **체인(Chains):** 여러 LLM 호출이나 다른 작업을 순차적으로 연결하여 복잡한 작업을 수행합니다.  예를 들어, 문서를 요약하고, 요약을 바탕으로 질문에 답하는 체인을 만들 수 있습니다.
#     * **에이전트(Agents):** LLM이 외부 도구(검색 엔진, 계산기 등)를 사용하여 작업을 수행할 수 있도록 합니다.  LLM이 어떤 도구를 사용할지 스스로 결정하고, 작업을 완료합니다.
#     * **메모리:** LLM이 이전 상호 작용을 기억하여 컨텍스트를 유지할 수 있도록 합니다.
# * **장점:**  모듈성, 확장성, 다양한 기능 제공.  복잡한 LLM 애플리케이션을 쉽게 구축할 수 있습니다.
# * **단점:**  복잡한 애플리케이션을 구축할 때는 상당한 코드 작성이 필요할 수 있습니다.
#
#
# **LangGraph:**
#
# * **초점:**  **지식 그래프**를 기반으로 LLM의 기능을 향상시키는 프레임워크.  LLM의 제한된 지식과 팩트 체크 문제를 해결하기 위해 지식 그래프를 활용합니다.  즉, LLM의 지식을 보강하고 신뢰성을 높이는 데 중점을 둡니다.
# * **핵심 기능:**
#     * **지식 그래프 통합:**  외부 지식 그래프를 LLM과 연결하여 LLM이 더 정확하고 풍부한 정보에 접근할 수 있도록 합니다.
#     * **팩트 체크 및 검증:**  지식 그래프를 사용하여 LLM의 출력을 검증하고, 잘못된 정보를 수정합니다.
#     * **추론:**  지식 그래프의 관계를 활용하여 LLM이 더 복잡한 추론을 수행할 수 있도록 지원합니다.
# * **장점:**  LLM의 정확성과 신뢰성을 향상시킵니다.  팩트 체크 및 지식 기반 추론에 유용합니다.
# * **단점:**  지식 그래프의 구축 및 관리가 어려울 수 있습니다.  지식 그래프의 품질이 결과의 정확성에 큰 영향을 미칩니다.
#
#
# **요약:**
#
# | 특징        | LangChain                               | LangGraph                                   |
# |--------------|-------------------------------------------|---------------------------------------------|
# | **핵심 목표** | LLM 기반 애플리케이션 구축                 | LLM의 지식 및 신뢰성 향상                    |
# | **주요 기능** | 모듈, 체인, 에이전트, 메모리                 | 지식 그래프 통합, 팩트 체크, 추론             |
# | **강점**      | 모듈성, 확장성, 다양한 기능                 | 정확성 및 신뢰성 향상, 지식 기반 추론       |
# | **약점**      | 복잡한 애플리케이션 개발의 어려움           | 지식 그래프 구축 및 관리의 어려움             |
#
#
# 결론적으로, LangChain은 LLM을 활용한 다양한 애플리케이션을 구축하는 데 초점을 맞춘 반면, LangGraph는 LLM의 지식과 신뢰성을 향상시키는 데 초점을 맞춘 프레임워크입니다.  두 프레임워크는 상호 보완적인 관계에 있으며, 함께 사용하면 더욱 강력한 LLM 기반 시스템을 구축할 수 있습니다.  예를 들어, LangChain을 사용하여 애플리케이션을 구축하고, LangGraph를 사용하여 해당 애플리케이션의 정확성과 신뢰성을 높일 수 있습니다.

# %% [markdown]
# #### Gemini 모델별 특징
#
# * gemini-1.5-flash: 빠른 응답, 일반적인 작업에 적합
# * gemini-2.5-pro: 더 정확하고 복잡한 추론 작업
# * gemini-pro-vision: 이미지 처리 및 멀티모달 작업

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# API 키 설정
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key"

# 기본 모델 설정
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-pro",
    temperature=0.7
)

print("=" * 50)
print("예제 1: 기본 대화형 챗봇")
print("=" * 50)

# 대화형 프롬프트
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 친근하고 도움이 되는 AI 어시스턴트입니다."),
    ("human", "{user_input}")
])

chat_chain = chat_prompt | llm | StrOutputParser()
response1 = chat_chain.invoke({"user_input": "파이썬으로 리스트를 정렬하는 방법은?"})
print("응답:", response1)

print("\n" + "=" * 50)
print("예제 2: JSON 구조화 출력")
print("=" * 50)

json_prompt = PromptTemplate(
    template="""
다음 정보를 JSON 형태로 변환하세요:
{company_info}

형식: {{"name": "회사명", "year": "연도", "location": "위치"}}
""",
    input_variables=["company_info"]
)

json_chain = json_prompt | llm | StrOutputParser()
company_text = "네이버는 1999년에 설립된 한국의 IT 기업이며 본사는 경기도 성남에 있습니다."
response2 = json_chain.invoke({"company_info": company_text})
print("JSON 결과:", response2)
# Out:
# ==================================================
# 예제 1: 기본 대화형 챗봇
# ==================================================
# 응답: 안녕하세요! 파이썬으로 리스트를 정렬하는 방법은 정말 간단하고 강력하답니다. 크게 두 가지 방법이 있는데, 상황에 맞게 골라 쓰시면 돼요.
#
# 핵심은 **`sort()` 메서드**와 **`sorted()` 내장 함수**의 차이를 아는 것입니다.
#
# ### 1. `list.sort()` 메서드: 리스트 자체를 정렬
#
# 이 방법은 **원본 리스트를 직접 수정**해서 정렬합니다. 리스트에만 사용할 수 있는 '메서드'입니다.
#
# - **특징**:
#   - 원본 리스트가 변경됩니다.
#   - 반환(return)하는 값이 없습니다 (`None`을 반환합니다).
#   - 더 이상 원본 순서가 필요 없을 때 사용하면 메모리를 효율적으로 쓸 수 있습니다.
#
# **기본 사용법 (오름차순)**
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2]
# print(f"정렬 전: {numbers}")
#
# # numbers 리스트 자체를 정렬합니다.
# numbers.sort()
#
# print(f"정렬 후: {numbers}")
#
# # 주의! 이렇게 사용하면 안 됩니다. new_list에는 None이 저장돼요.
# # new_list = numbers.sort()
# # print(new_list) # 출력: None
# ```
#
# **결과:**
# ```
# 정렬 전: [3, 1, 4, 1, 5, 9, 2]
# 정렬 후: [1, 1, 2, 3, 4, 5, 9]
# ```
#
# **내림차순 정렬**
#
# `reverse=True` 옵션을 주면 내림차순으로 정렬할 수 있습니다.
#
# ```python
# fruits = ['apple', 'orange', 'banana', 'cherry']
# fruits.sort(reverse=True)
# print(fruits)
# ```
#
# **결과:**
# ```
# ['orange', 'cherry', 'banana', 'apple']
# ```
#
# ---
#
# ### 2. `sorted()` 내장 함수: 새로운 정렬된 리스트 반환
#
# 이 방법은 **원본 리스트는 그대로 두고**, 정렬된 **새로운 리스트를 만들어서 반환**합니다. 리스트뿐만 아니라 튜플, 문자열 등 반복 가능한(iterable) 모든 것을 정렬할 수 있습니다.
#
# - **특징**:
#   - 원본 리스트가 변경되지 않습니다.
#   - 정렬된 '새로운' 리스트를 반환합니다.
#   - 원본 순서를 유지하면서 정렬된 버전이 필요할 때 사용합니다.
#
# **기본 사용법 (오름차순)**
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2]
# print(f"원본 리스트: {numbers}")
#
# # 정렬된 '새로운' 리스트를 new_numbers에 저장합니다.
# new_numbers = sorted(numbers)
#
# print(f"새로운 정렬된 리스트: {new_numbers}")
# print(f"원본 리스트 (그대로): {numbers}")
# ```
#
# **결과:**
# ```
# 원본 리스트: [3, 1, 4, 1, 5, 9, 2]
# 새로운 정렬된 리스트: [1, 1, 2, 3, 4, 5, 9]
# 원본 리스트 (그대로): [3, 1, 4, 1, 5, 9, 2]
# ```
#
# **내림차순 정렬**
#
# `sort()`와 마찬가지로 `reverse=True` 옵션을 사용합니다.
#
# ```python
# scores = [88, 95, 70, 100, 99]
# sorted_scores = sorted(scores, reverse=True)
# print(sorted_scores)
# ```
#
# **결과:**
# ```
# [100, 99, 95, 88, 70]
# ```
#
# ---
#
# ### 📊 `sort()` vs `sorted()` 비교 정리
#
# | 구분 | `list.sort()` | `sorted()` |
# | :--- | :--- | :--- |
# | **형태** | 리스트 메서드 (`my_list.sort()`) | 내장 함수 (`sorted(my_list)`) |
# | **원본 변경** | **변경함 (in-place)** | **변경 안 함** |
# | **반환 값** | `None` (없음) | **정렬된 새 리스트** |
# | **사용 대상** | 리스트만 가능 | 모든 반복 가능한 객체 (리스트, 튜플 등) |
#
# ---
#
# ### ✨ 심화: `key` 매개변수를 이용한 정렬 기준 설정
#
# `sort()`와 `sorted()` 모두 `key`라는 아주 유용한 옵션을 제공합니다. `key`에 함수를 지정하면, 각 요소를 그 함수에 통과시킨 결과를 기준으로 정렬합니다.
#
# **예시 1: 문자열 길이를 기준으로 정렬하기**
#
# ```python
# words = ["python", "is", "awesome", "and", "fun"]
#
# # len 함수를 key로 사용하여 단어 길이를 기준으로 정렬
# sorted_by_length = sorted(words, key=len)
# print(sorted_by_length)
# ```
#
# **결과:** (길이가 짧은 순서대로 정렬됨)
# ```
# ['is', 'and', 'fun', 'python', 'awesome']
# ```
#
# **예시 2: 대소문자 구분 없이 알파벳순으로 정렬하기**
#
# ```python
# mixed_case = ['Apple', 'banana', 'Cherry', 'apple']
#
# # 기본 정렬 (대문자가 소문자보다 먼저 옴)
# print(f"기본 정렬: {sorted(mixed_case)}")
#
# # str.lower 함수를 key로 주어 모두 소문자로 바꾼 후 비교
# sorted_case_insensitive = sorted(mixed_case, key=str.lower)
# print(f"대소문자 무시 정렬: {sorted_case_insensitive}")
# ```
#
# **결과:**
# ```
# 기본 정렬: ['Apple', 'Cherry', 'apple', 'banana']
# 대소문자 무시 정렬: ['Apple', 'apple', 'banana', 'Cherry']
# ```
#
# **예시 3: 복잡한 리스트(튜플, 딕셔너리) 정렬하기**
#
# 학생의 (이름, 점수) 튜플 리스트를 점수 기준으로 정렬하고 싶을 때 `lambda` 함수를 `key`로 자주 사용합니다.
#
# ```python
# students = [('Alice', 90), ('Bob', 85), ('Charlie', 95)]
#
# # 각 튜플(x)의 두 번째 요소(x[1], 즉 점수)를 기준으로 정렬
# sorted_by_score = sorted(students, key=lambda x: x[1], reverse=True) # 점수 높은 순
# print(sorted_by_score)
# ```
#
# **결과:**
# ```
# [('Charlie', 95), ('Alice', 90), ('Bob', 85)]
# ```
#
# ### 💡 언제 무엇을 써야 할까요?
#
# *   **`list.sort()`**: 원본 리스트가 더 이상 필요 없고, 메모리를 아끼고 싶을 때 사용하세요.
# *   **`sorted()`**: 원본 리스트를 보존해야 하거나, 튜플처럼 수정 불가능한 객체를 정렬할 때 사용하세요. 일반적으로 더 안전하고 많이 쓰이는 방법입니다.
#
# 더 궁금한 점이 있으시면 언제든지 다시 물어보세요
#
# ==================================================
# 예제 2: JSON 구조화 출력
# ==================================================
# JSON 결과: ```json
# {
#   "name": "네이버",
#   "year": "1999",
#   "location": "경기도 성남"
# }
# ```

# %%
print("\n" + "=" * 50)
print("예제 3: 번역 체인")
print("=" * 50)

translate_prompt = ChatPromptTemplate.from_template(
    "다음 텍스트를 {target_language}로 번역하세요: {text}"
)

translate_chain = translate_prompt | llm | StrOutputParser()
original = "Hello, how are you today?"
translated = translate_chain.invoke({
    "text": original, 
    "target_language": "한국어"
})
print("번역 결과:", translated)

print("\n" + "=" * 50)
print("예제 4: 감정 분석")
print("=" * 50)

emotion_prompt = ChatPromptTemplate.from_template("""
텍스트: {text}
감정을 분석하고 [긍정/부정/중립]과 1-10점수를 매기세요.
""")

emotion_chain = emotion_prompt | llm | StrOutputParser()
test_text = "오늘 프로젝트가 성공적으로 완료되어서 정말 기쁩니다!"
emotion_result = emotion_chain.invoke({"text": test_text})
print("감정 분석:", emotion_result)

print("\n" + "=" * 50)
print("예제 5: 코드 생성")
print("=" * 50)

code_prompt = ChatPromptTemplate.from_template("""
{language}로 {task} 기능을 구현하는 간단한 코드를 작성하세요.
""")

code_chain = code_prompt | llm | StrOutputParser()
code_result = code_chain.invoke({
    "language": "Python",
    "task": "두 숫자의 최대공약수를 구하는"
})
print("생성된 코드:")
print(code_result)

print("\n" + "=" * 50)
print("예제 6: 창의적 콘텐츠 생성")
print("=" * 50)

# %%
# 창의적 생성용 높은 temperature
llm_creative = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0.9
)

creative_prompt = ChatPromptTemplate.from_template(
    "{topic}에 대한 창의적인 {content_type}를 {style} 스타일로 작성하세요."
)

creative_chain = creative_prompt | llm_creative | StrOutputParser()
creative_result = creative_chain.invoke({
    "topic": "미래의 교통수단",
    "content_type": "아이디어",
    "style": "혁신적이고 실현 가능한"
})
print("창의적 아이디어:", creative_result)

print("\n" + "=" * 50)
print("Gemini 모델 옵션")
print("=" * 50)
print("• gemini-1.5-flash: 빠른 응답, 일반 작업")
print("• gemini-1.5-pro: 정확한 분석, 복잡한 추론")
print("• gemini-pro-vision: 이미지 처리 가능")
print("• temperature: 0.1(정확) ~ 0.9(창의적)")
print("=" * 50)
