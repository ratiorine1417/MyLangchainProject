# %% [markdown]
# #### LangSmith 기본 예제

# %% [markdown]
# ##### 1) 라이브러리 설치

# %%
# poetry add langsmith

# %% [markdown]
# ##### 2) OpenAI 인증키 설정

# %%
import os
from dotenv import load_dotenv
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv(dotenv_path='../.env')

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_n

# %% [markdown]
# ##### LangSmith와 LangChain을 활용한 기본 로깅 예제

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langsmith import traceable

# LangSmith API Key 설정
os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")  # LangSmith 활성화
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")  # API Key 불러오기
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")   # 프로젝트 이름 설정
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")   # EndPoint 설정

# LLM 모델 설정 (OpenAI 사용)
#llm = ChatOpenAI(model="gpt-3.5-turbo")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# LangSmith로 실행 추적
@traceable(run_type="chain", name="Simple_Chain")
def ask_question(question: str):

    # 개별 메시지 템플릿 정의
    system_message = SystemMessagePromptTemplate.from_template(
        "당신은 유용한 AI 비서입니다."
    )
    user_message = HumanMessagePromptTemplate.from_template(
        "{question}"
    )

    chat_prompt = ChatPromptTemplate.from_messages([
        system_message,
        user_message,
    ])
    
    messages = chat_prompt.format_messages(question=question)
    response = llm.invoke(messages)

    return response.content

# 테스트 실행
question = "LangGraph와 LangChain의 차이점은 무엇인가요?"
answer = ask_question(question)

# 결과 출력
print("\n🔹 [AI 답변]:")
print(answer)
# Out:
# 🔹 [AI 답변]:
# LangGraph와 LangChain은 모두 언어 모델을 활용하여 애플리케이션을 구축하기 위한 라이브러리이지만, 두 라이브러리는 다른 디자인 철학과 사용 사례에 중점을 둡니다.
#
# LangChain은 대규모 언어 모델(LLMs)을 사용하여 애플리케이션을 구축하기 위한 프레임워크입니다. LangChain을 사용하면 개발자가 언어 모델을 호출하고, 프롬프트를 관리하며, 다른 도구 및 API와 통합하는 등의 작업을 쉽게 할 수 있습니다. LangChain은 모듈식 설계와 확장성을 강조합니다. 주요 목표는 개발자가 언어 모델을 사용하여 애플리케이션을 빠르고 쉽게 구축할 수 있도록 하는 것입니다.
#
# LangGraph는 LangChain을 기반으로 구축된 라이브러리로, LangChain의 기능을 확장하고 강화합니다. LangGraph는 다중 단계 워크플로우 및 에이전트 기반 아키텍처에 중점을 둡니다. LangGraph를 사용하면 개발자가 여러 단계로 구성된 복잡한 워크플로우를 정의하고, 각 단계에서 언어 모델을 호출하고, 다양한 도구 및 API와 통합할 수 있습니다. LangGraph는 LangChain보다 더 높은 수준의 추상화를 제공하며, 복잡한 애플리케이션을 구축하기 위한 더 많은 기능을 제공합니다.
#
# 즉, LangChain은 언어 모델을 사용하여 애플리케이션을 구축하기 위한 기본 라이브러리이고, LangGraph는 LangChain을 기반으로 구축된 라이브러리로, 더 복잡한 워크플로우 및 에이전트 기반 아키텍처를 지원합니다. LangChain은 더 낮은 수준의 API를 제공하며, 개발자가 더 많은 제어를 필요로 하는 경우에 적합합니다. LangGraph는 더 높은 수준의 추상화를 제공하며, 복잡한 애플리케이션을 빠르고 쉽게 구축하려는 개발자에게 적합합니다.
